# %%
import pymysql
import sqlalchemy as alch 
from getpass import getpass
import pandas as pd

# %%
password = getpass("Please enter your password: ")
dbName = "Ironhack"
con=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(con)

# %%
import pandas as pd
all_restaurants_languages = pd.read_csv('../csv/df_all_languages_translated.csv')

# %%
all_restaurants_languages.to_sql('Tripadvisor', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Tim_K\miniconda3\lib\site-packages\pymysql\connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File c:\Users\Tim_K\miniconda3\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File c:\Users\Tim_K\miniconda3\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# ...
