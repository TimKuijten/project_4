# %%
import pymysql
import sqlalchemy as alch # python -m pip install --upgrade 'sqlalchemy<2.0'
from getpass import getpass
import pandas as pd

# %%
password = getpass("Please enter your password: ")
dbName = "tripadvisor"
con=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(con)

# %%
pd.read_sql_query("""
CREATE DATABASE IF NOT EXISTS tripadvisor;
""", engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# c:\Users\Tim_K\Ironhack\project_4\mysql\queries.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tim_K/Ironhack/project_4/mysql/queries.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> pd.read_sql_query("""
#       <a href='vscode-notebook-cell:/c%3A/Users/Tim_K/Ironhack/project_4/mysql/queries.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> CREATE DATABASE IF NOT EXISTS tripadvisor;
#       <a href='vscode-notebook-cell:/c%3A/Users/Tim_K/Ironhack/project_4/mysql/queries.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> """, engine)
#
# File c:\Users\Tim_K\miniconda3\lib\site-packages\pandas\io\sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
# ...

# %%
pd.read_sql_query("""
LOAD DATA LOCAL INFILE '../csv/df_all_languages_translated.csv'
INTO TABLE all_languages
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\r\n';
""", engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Tim_K\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File c:\Users\Tim_K\miniconda3\lib\site-packages\sqlalchemy\engine\default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# File c:\Users\Tim_K\miniconda3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
# ...
